# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../src/guide_mod.csv")

# %%
df["segment_nostress"].unique()
# Out:
# array(['sil', 'CH', 'AE', 'P', 'T', 'ER', 'W', 'AH', 'N', 'sp', 'M', 'IH',
#        'S', 'Z', 'R', 'EY', 'L', 'D', 'AY', 'V', 'JH', 'EH', 'DH', 'IY',
#        'OW', 'AW', 'UW', 'HH', 'AA', 'F', 'TH', 'AO', 'B', 'UH', 'K', 'Y',
#        'NG', 'G', 'SH', 'OY', 'ZH', 'spn'], dtype=object)

# %%
ls = ['CH', 'AE', 'P', 'T', 'ER', 'W', 'N', 'M', 'IH',
       'S', 'Z', 'R', 'EY', 'L', 'D', 'AY', 'V', 'JH', 'EH', 'DH', 'IY',
       'OW', 'AW', 'UW', 'HH', 'AA', 'F', 'TH', 'AO', 'B', 'UH', 'K', 'Y',
       'NG', 'G', 'SH', 'OY', 'ZH']

# %%
sorted(ls)
# Out:
# ['AA',
#  'AE',
#  'AO',
#  'AW',
#  'AY',
#  'B',
#  'CH',
#  'D',
#  'DH',
#  'EH',
#  'ER',
#  'EY',
#  'F',
#  'G',
#  'HH',
#  'IH',
#  'IY',
#  'JH',
#  'K',
#  'L',
#  'M',
#  'N',
#  'NG',
#  'OW',
#  'OY',
#  'P',
#  'R',
#  'S',
#  'SH',
#  'T',
#  'TH',
#  'UH',
#  'UW',
#  'V',
#  'W',
#  'Y',
#  'Z',
#  'ZH']
