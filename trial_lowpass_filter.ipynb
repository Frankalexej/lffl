# %%
import torchaudio
from torchaudio import transforms
from scipy.io import wavfile
import torch

# %%
from preproc_lowpass_filter import lowpass_filter
from misc_tools import MyAudio
from paths import *

# %%
wav_filename = train_audio_ + "19/198/19-198-0011.flac"
cut_off_freq = 500

# %%
data, fs = torchaudio.load(wav_filename)

# %%
ori = data

# %%
MyAudio.play_audio_torch(data, sample_rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data = data.squeeze()
data = data.numpy()

# %%
filtered = lowpass_filter(data,fs,cut_off_freq)

# %%
filtered = torch.tensor(filtered)
filtered = filtered.unsqueeze(0)

# %%
MyAudio.play_audio_torch(filtered, sample_rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
torchaudio.save("before.falc", data, sample_rate=fs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# a:\Projects\lffl\scripts\trial_lowpass_filter.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/a%3A/Projects/lffl/scripts/trial_lowpass_filter.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> torchaudio.save("before.falc", sample_rate=fs)
#
# TypeError: get_save_func.<locals>.save() missing 1 required positional argument: 'src'
