# %%
import torchaudio
from torchaudio import transforms
from scipy.io import wavfile
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from model_filter import lowpass_filter, XpassFilter
from misc_tools import MyAudio
from paths import *

# %%
wav_filename = train_audio_ + "19/198/19-198-0011.flac"
cut_off_freq = 500

high_off_lower = 4000
high_off_upper = 10000

# %%
data, fs = torchaudio.load(wav_filename)

# %%
lowfilter = XpassFilter(cut_off_upper=cut_off_freq)

# %%
lowout = lowfilter(data, fs)

# %%
MyAudio.play_audio_torch(lowout, sample_rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
cosine_similarity = F.cosine_similarity(lowout, filtered)

# %%
lowout
# Out:
# tensor([[-0.0031, -0.0029, -0.0027,  ..., -0.0034, -0.0034, -0.0033]])

# %%
filtered
# Out:
# tensor([[-0.0032, -0.0030, -0.0027,  ..., -0.0034, -0.0034, -0.0033]])

# %% [markdown]
# - conclusion: numpy and torch code are matching.

# %%
cosine_similarity
# Out:
# tensor([1.0000])

# %%
ori = data

# %%
MyAudio.play_audio_torch(data, sample_rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data = data.squeeze()
data = data.numpy()

# %%
filtered = lowpass_filter(data,fs,cut_off_freq)
filtered = torch.tensor(filtered)
filtered = filtered.unsqueeze(0)

# %%
MyAudio.play_audio_torch(filtered, sample_rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
high_filtered = lowpass_filter(data, fs, high_off_upper, high_off_lower)
high_filtered = torch.tensor(high_filtered)
high_filtered = high_filtered.unsqueeze(0)

# %%
MyAudio.play_audio_torch(high_filtered, sample_rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
torchaudio.save("before.wav", ori, sample_rate=fs)

# %%
torchaudio.save("after.wav", filtered, sample_rate=fs)
